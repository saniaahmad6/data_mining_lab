# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
# data 
csv_url = "https://drive.google.com/uc?export=download&id=1qWnl8VXNl_lWSD8WBvJTvvtEycfejiqJ"
df = pd.read_csv(csv_url,low_memory=False)

df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# ...

# %%
len(df) # total entries
# Out:
# 39717

# %%
list(df.groupby("grade"))
# Out:
# [('A',
#               id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
#   5      1075269    1311441       5000         5000           5000.0
#   17     1069971    1304884       3600         3600           3600.0
#   19     1069742    1304855       9200         9200           9200.0
#   30     1032111    1261745       4375         4375           4375.0
#   31     1069539    1304608      31825        31825          31825.0
#   ...        ...        ...        ...          ...              ...
#   39706    92676      92671       5000         5000            150.0
#   39710    92507      92502       5000         5000            250.0
#   39712    92187      92174       2500         2500           1075.0
#   39714    90395      90390       5000         5000           1325.0
#   39715    90376      89243       5000         5000            650.0
#
#                term int_rate  installment grade sub_grade  ...  \
#   5       36 months    7.90%       156.46     A        A4  ...
# ...

# %%
df.groupby("grade").count()
# Out:
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv   term  \
# grade
# A      10085      10085      10085        10085            10085  10085
# B      12020      12020      12020        12020            12020  12020
# C       8098       8098       8098         8098             8098   8098
# D       5307       5307       5307         5307             5307   5307
# E       2842       2842       2842         2842             2842   2842
# F       1049       1049       1049         1049             1049   1049
# G        316        316        316          316              316    316
#
#        int_rate  installment  sub_grade  emp_title  ...  num_tl_90g_dpd_24m  \
# grade                                               ...
# A         10085        10085      10085       9320  ...                   0
# B         12020        12020      12020      11271  ...                   0
# C          8098         8098       8098       7651  ...                   0
# ...
